# %% [markdown]
# # Character-level recurrent sequence-to-sequence model
#
# **Author:** [fchollet](https://twitter.com/fchollet)<br>
# **Date created:** 2017/09/29<br>
# **Last modified:** 2020/04/26<br>
# **Description:** Character-level recurrent sequence-to-sequence model.

# %% [markdown]
# ## Introduction
#
# This example demonstrates how to implement a basic character-level
# recurrent sequence-to-sequence model. We apply it to translating
# short English sentences into short French sentences,
# character-by-character. Note that it is fairly unusual to
# do character-level machine translation, as word-level
# models are more common in this domain.
#
# **Summary of the algorithm**
#
# - We start with input sequences from a domain (e.g. English sentences)
#     and corresponding target sequences from another domain
#     (e.g. French sentences).
# - An encoder LSTM turns input sequences to 2 state vectors
#     (we keep the last LSTM state and discard the outputs).
# - A decoder LSTM is trained to turn the target sequences into
#     the same sequence but offset by one timestep in the future,
#     a training process called "teacher forcing" in this context.
#     It uses as initial state the state vectors from the encoder.
#     Effectively, the decoder learns to generate `targets[t+1...]`
#     given `targets[...t]`, conditioned on the input sequence.
# - In inference mode, when we want to decode unknown input sequences, we:
#     - Encode the input sequence into state vectors
#     - Start with a target sequence of size 1
#         (just the start-of-sequence character)
#     - Feed the state vectors and 1-char target sequence
#         to the decoder to produce predictions for the next character
#     - Sample the next character using these predictions
#         (we simply use argmax).
#     - Append the sampled character to the target sequence
#     - Repeat until we generate the end-of-sequence character or we
#         hit the character limit.

# %% [markdown]
# ## Setup

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# ## Download the data

# %%
# !!curl -O http://www.manythings.org/anki/fra-eng.zip
# !!unzip fra-eng.zip

# %% [markdown]
# ## Configuration

# %%
batch_size = 64  # Batch size for training.
epochs = 100  # Number of epochs to train for.
latent_dim = 256  # Latent dimensionality of the encoding space.
num_samples = 10000  # Number of samples to train on.
# Path to the data txt file on disk.
data_path = "fra.txt"

# %% [markdown]
# ## Prepare the data

# %%
# Vectorize the data.
input_texts = []
target_texts = []
input_characters = set()
target_characters = set()
with open(data_path, "r", encoding="utf-8") as f:
    lines = f.read().split("\n")
for line in lines[: min(num_samples, len(lines) - 1)]:
    input_text, target_text, _ = line.split("\t")
    # We use "tab" as the "start sequence" character
    # for the targets, and "\n" as "end sequence" character.
    target_text = "\t" + target_text + "\n"
    input_texts.append(input_text)
    target_texts.append(target_text)
    for char in input_text:
        if char not in input_characters:
            input_characters.add(char)
    for char in target_text:
        if char not in target_characters:
            target_characters.add(char)

input_characters = sorted(list(input_characters))
target_characters = sorted(list(target_characters))
num_encoder_tokens = len(input_characters)
num_decoder_tokens = len(target_characters)
max_encoder_seq_length = max([len(txt) for txt in input_texts])
max_decoder_seq_length = max([len(txt) for txt in target_texts])

print("Number of samples:", len(input_texts))
print("Number of unique input tokens:", num_encoder_tokens)
print("Number of unique output tokens:", num_decoder_tokens)
print("Max sequence length for inputs:", max_encoder_seq_length)
print("Max sequence length for outputs:", max_decoder_seq_length)

input_token_index = dict([(char, i) for i, char in enumerate(input_characters)])
target_token_index = dict([(char, i) for i, char in enumerate(target_characters)])

encoder_input_data = np.zeros(
    (len(input_texts), max_encoder_seq_length, num_encoder_tokens), dtype="float32"
)
decoder_input_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens), dtype="float32"
)
decoder_target_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens), dtype="float32"
)

for i, (input_text, target_text) in enumerate(zip(input_texts, target_texts)):
    for t, char in enumerate(input_text):
        encoder_input_data[i, t, input_token_index[char]] = 1.0
    encoder_input_data[i, t + 1 :, input_token_index[" "]] = 1.0
    for t, char in enumerate(target_text):
        # decoder_target_data is ahead of decoder_input_data by one timestep
        decoder_input_data[i, t, target_token_index[char]] = 1.0
        if t > 0:
            # decoder_target_data will be ahead by one timestep
            # and will not include the start character.
            decoder_target_data[i, t - 1, target_token_index[char]] = 1.0
    decoder_input_data[i, t + 1 :, target_token_index[" "]] = 1.0
    decoder_target_data[i, t:, target_token_index[" "]] = 1.0
# Out:
# Number of samples: 10000
# Number of unique input tokens: 70
# Number of unique output tokens: 93
# Max sequence length for inputs: 14
# Max sequence length for outputs: 59

# %% [markdown]
# ## Build the model

# %%
# Define an input sequence and process it.
encoder_inputs = keras.Input(shape=(None, num_encoder_tokens))
encoder = keras.layers.LSTM(latent_dim, return_state=True)
encoder_outputs, state_h, state_c = encoder(encoder_inputs)

# We discard `encoder_outputs` and only keep the states.
encoder_states = [state_h, state_c]

# Set up the decoder, using `encoder_states` as initial state.
decoder_inputs = keras.Input(shape=(None, num_decoder_tokens))

# We set up our decoder to return full output sequences,
# and to return internal states as well. We don't use the
# return states in the training model, but we will use them in inference.
decoder_lstm = keras.layers.LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_inputs, initial_state=encoder_states)
decoder_dense = keras.layers.Dense(num_decoder_tokens, activation="softmax")
decoder_outputs = decoder_dense(decoder_outputs)

# Define the model that will turn
# `encoder_input_data` & `decoder_input_data` into `decoder_target_data`
model = keras.Model([encoder_inputs, decoder_inputs], decoder_outputs)

# %% [markdown]
# ## Train the model

# %%
model.compile(
    optimizer="rmsprop", loss="categorical_crossentropy", metrics=["accuracy"]
)
model.fit(
    [encoder_input_data, decoder_input_data],
    decoder_target_data,
    batch_size=batch_size,
    epochs=epochs,
    validation_split=0.2,
)
# Save model
model.save("s2s")
# Out:
# Epoch 1/100
# 125/125 [==============================] - 7s 26ms/step - loss: 1.2107 - accuracy: 0.7335 - val_loss: 1.0828 - val_accuracy: 0.7098
# Epoch 2/100
# 125/125 [==============================] - 2s 20ms/step - loss: 0.9355 - accuracy: 0.7478 - val_loss: 0.9628 - val_accuracy: 0.7284
# Epoch 3/100
# 125/125 [==============================] - 2s 20ms/step - loss: 0.8367 - accuracy: 0.7672 - val_loss: 0.8679 - val_accuracy: 0.7514
# Epoch 4/100
# 125/125 [==============================] - 2s 20ms/step - loss: 0.7478 - accuracy: 0.7882 - val_loss: 0.7668 - val_accuracy: 0.7781
# Epoch 5/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.6791 - accuracy: 0.8054 - val_loss: 0.7157 - val_accuracy: 0.7949
# Epoch 6/100
# 125/125 [==============================] - 2s 20ms/step - loss: 0.6297 - accuracy: 0.8170 - val_loss: 0.6939 - val_accuracy: 0.7966
# Epoch 7/100
# 125/125 [==============================] - 2s 20ms/step - loss: 0.6007 - accuracy: 0.8244 - val_loss: 0.6631 - val_accuracy: 0.8056
# Epoch 8/100
# 125/125 [==============================] - 2s 20ms/step - loss: 0.5776 - accuracy: 0.8307 - val_loss: 0.6343 - val_accuracy: 0.8152
# Epoch 9/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.5577 - accuracy: 0.8365 - val_loss: 0.6129 - val_accuracy: 0.8213
# Epoch 10/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.5399 - accuracy: 0.8414 - val_loss: 0.5972 - val_accuracy: 0.8264
# Epoch 11/100
# 125/125 [==============================] - 2s 20ms/step - loss: 0.5239 - accuracy: 0.8466 - val_loss: 0.5841 - val_accuracy: 0.8296
# Epoch 12/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.5084 - accuracy: 0.8511 - val_loss: 0.5740 - val_accuracy: 0.8334
# Epoch 13/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.4940 - accuracy: 0.8553 - val_loss: 0.5566 - val_accuracy: 0.8385
# Epoch 14/100
# 125/125 [==============================] - 2s 20ms/step - loss: 0.4813 - accuracy: 0.8590 - val_loss: 0.5478 - val_accuracy: 0.8407
# Epoch 15/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.4700 - accuracy: 0.8619 - val_loss: 0.5357 - val_accuracy: 0.8443
# Epoch 16/100
# 125/125 [==============================] - 2s 20ms/step - loss: 0.4585 - accuracy: 0.8653 - val_loss: 0.5243 - val_accuracy: 0.8485
# Epoch 17/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.4488 - accuracy: 0.8679 - val_loss: 0.5213 - val_accuracy: 0.8481
# Epoch 18/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.4400 - accuracy: 0.8700 - val_loss: 0.5107 - val_accuracy: 0.8506
# Epoch 19/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.4307 - accuracy: 0.8726 - val_loss: 0.5061 - val_accuracy: 0.8517
# Epoch 20/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.4224 - accuracy: 0.8751 - val_loss: 0.5013 - val_accuracy: 0.8533
# Epoch 21/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.4151 - accuracy: 0.8771 - val_loss: 0.4920 - val_accuracy: 0.8559
# Epoch 22/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.4070 - accuracy: 0.8796 - val_loss: 0.4890 - val_accuracy: 0.8567
# Epoch 23/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.4006 - accuracy: 0.8813 - val_loss: 0.4821 - val_accuracy: 0.8588
# Epoch 24/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.3934 - accuracy: 0.8833 - val_loss: 0.4790 - val_accuracy: 0.8593
# Epoch 25/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.3865 - accuracy: 0.8856 - val_loss: 0.4710 - val_accuracy: 0.8612
# Epoch 26/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.3807 - accuracy: 0.8871 - val_loss: 0.4731 - val_accuracy: 0.8623
# Epoch 27/100
# 125/125 [==============================] - 2s 20ms/step - loss: 0.3748 - accuracy: 0.8886 - val_loss: 0.4658 - val_accuracy: 0.8638
# Epoch 28/100
# 125/125 [==============================] - 2s 20ms/step - loss: 0.3688 - accuracy: 0.8900 - val_loss: 0.4647 - val_accuracy: 0.8642
# Epoch 29/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.3630 - accuracy: 0.8918 - val_loss: 0.4614 - val_accuracy: 0.8650
# Epoch 30/100
# 125/125 [==============================] - 2s 20ms/step - loss: 0.3578 - accuracy: 0.8936 - val_loss: 0.4578 - val_accuracy: 0.8663
# Epoch 31/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.3522 - accuracy: 0.8950 - val_loss: 0.4579 - val_accuracy: 0.8658
# Epoch 32/100
# 125/125 [==============================] - 3s 22ms/step - loss: 0.3471 - accuracy: 0.8965 - val_loss: 0.4564 - val_accuracy: 0.8664
# Epoch 33/100
# 125/125 [==============================] - 3s 21ms/step - loss: 0.3416 - accuracy: 0.8982 - val_loss: 0.4529 - val_accuracy: 0.8678
# Epoch 34/100
# 125/125 [==============================] - 3s 21ms/step - loss: 0.3368 - accuracy: 0.8994 - val_loss: 0.4511 - val_accuracy: 0.8683
# Epoch 35/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.3318 - accuracy: 0.9010 - val_loss: 0.4510 - val_accuracy: 0.8686
# Epoch 36/100
# 125/125 [==============================] - 3s 21ms/step - loss: 0.3269 - accuracy: 0.9022 - val_loss: 0.4434 - val_accuracy: 0.8708
# Epoch 37/100
# 125/125 [==============================] - 3s 21ms/step - loss: 0.3225 - accuracy: 0.9037 - val_loss: 0.4509 - val_accuracy: 0.8689
# Epoch 38/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.3176 - accuracy: 0.9051 - val_loss: 0.4464 - val_accuracy: 0.8697
# Epoch 39/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.3133 - accuracy: 0.9062 - val_loss: 0.4430 - val_accuracy: 0.8718
# Epoch 40/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.3089 - accuracy: 0.9077 - val_loss: 0.4406 - val_accuracy: 0.8713
# Epoch 41/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.3045 - accuracy: 0.9086 - val_loss: 0.4405 - val_accuracy: 0.8719
# Epoch 42/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.3003 - accuracy: 0.9102 - val_loss: 0.4400 - val_accuracy: 0.8731
# Epoch 43/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.2959 - accuracy: 0.9114 - val_loss: 0.4434 - val_accuracy: 0.8722
# Epoch 44/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.2920 - accuracy: 0.9126 - val_loss: 0.4403 - val_accuracy: 0.8726
# Epoch 45/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.2880 - accuracy: 0.9139 - val_loss: 0.4411 - val_accuracy: 0.8727
# Epoch 46/100
# 125/125 [==============================] - 2s 20ms/step - loss: 0.2841 - accuracy: 0.9149 - val_loss: 0.4392 - val_accuracy: 0.8740
# Epoch 47/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.2803 - accuracy: 0.9159 - val_loss: 0.4377 - val_accuracy: 0.8737
# Epoch 48/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.2761 - accuracy: 0.9171 - val_loss: 0.4381 - val_accuracy: 0.8747
# Epoch 49/100
# 125/125 [==============================] - 2s 20ms/step - loss: 0.2725 - accuracy: 0.9185 - val_loss: 0.4381 - val_accuracy: 0.8754
# Epoch 50/100
# 125/125 [==============================] - 2s 20ms/step - loss: 0.2685 - accuracy: 0.9194 - val_loss: 0.4399 - val_accuracy: 0.8741
# Epoch 51/100
# 125/125 [==============================] - 2s 20ms/step - loss: 0.2654 - accuracy: 0.9202 - val_loss: 0.4388 - val_accuracy: 0.8745
# Epoch 52/100
# 125/125 [==============================] - 2s 20ms/step - loss: 0.2614 - accuracy: 0.9216 - val_loss: 0.4410 - val_accuracy: 0.8749
# Epoch 53/100
# 125/125 [==============================] - 2s 20ms/step - loss: 0.2577 - accuracy: 0.9224 - val_loss: 0.4422 - val_accuracy: 0.8752
# Epoch 54/100
# 125/125 [==============================] - 2s 20ms/step - loss: 0.2546 - accuracy: 0.9235 - val_loss: 0.4439 - val_accuracy: 0.8746
# Epoch 55/100
# 125/125 [==============================] - 2s 20ms/step - loss: 0.2507 - accuracy: 0.9245 - val_loss: 0.4417 - val_accuracy: 0.8751
# Epoch 56/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.2475 - accuracy: 0.9253 - val_loss: 0.4434 - val_accuracy: 0.8757
# Epoch 57/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.2441 - accuracy: 0.9263 - val_loss: 0.4478 - val_accuracy: 0.8749
# Epoch 58/100
# 125/125 [==============================] - 2s 20ms/step - loss: 0.2407 - accuracy: 0.9276 - val_loss: 0.4429 - val_accuracy: 0.8765
# Epoch 59/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.2379 - accuracy: 0.9283 - val_loss: 0.4506 - val_accuracy: 0.8757
# Epoch 60/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.2345 - accuracy: 0.9294 - val_loss: 0.4468 - val_accuracy: 0.8759
# Epoch 61/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.2315 - accuracy: 0.9303 - val_loss: 0.4451 - val_accuracy: 0.8768
# Epoch 62/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.2282 - accuracy: 0.9313 - val_loss: 0.4478 - val_accuracy: 0.8762
# Epoch 63/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.2248 - accuracy: 0.9323 - val_loss: 0.4502 - val_accuracy: 0.8760
# Epoch 64/100
# 125/125 [==============================] - 2s 20ms/step - loss: 0.2218 - accuracy: 0.9331 - val_loss: 0.4500 - val_accuracy: 0.8769
# Epoch 65/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.2189 - accuracy: 0.9342 - val_loss: 0.4529 - val_accuracy: 0.8771
# Epoch 66/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.2161 - accuracy: 0.9352 - val_loss: 0.4569 - val_accuracy: 0.8759
# Epoch 67/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.2135 - accuracy: 0.9357 - val_loss: 0.4583 - val_accuracy: 0.8763
# Epoch 68/100
# 125/125 [==============================] - 2s 20ms/step - loss: 0.2101 - accuracy: 0.9366 - val_loss: 0.4562 - val_accuracy: 0.8774
# Epoch 69/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.2079 - accuracy: 0.9370 - val_loss: 0.4560 - val_accuracy: 0.8776
# Epoch 70/100
# 125/125 [==============================] - 2s 20ms/step - loss: 0.2052 - accuracy: 0.9381 - val_loss: 0.4566 - val_accuracy: 0.8771
# Epoch 71/100
# 125/125 [==============================] - 2s 20ms/step - loss: 0.2017 - accuracy: 0.9391 - val_loss: 0.4577 - val_accuracy: 0.8785
# Epoch 72/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.1992 - accuracy: 0.9399 - val_loss: 0.4670 - val_accuracy: 0.8764
# Epoch 73/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.1966 - accuracy: 0.9407 - val_loss: 0.4645 - val_accuracy: 0.8775
# Epoch 74/100
# 125/125 [==============================] - 2s 20ms/step - loss: 0.1940 - accuracy: 0.9412 - val_loss: 0.4679 - val_accuracy: 0.8771
# Epoch 75/100
# 125/125 [==============================] - 2s 20ms/step - loss: 0.1916 - accuracy: 0.9422 - val_loss: 0.4676 - val_accuracy: 0.8775
# Epoch 76/100
# 125/125 [==============================] - 2s 20ms/step - loss: 0.1892 - accuracy: 0.9431 - val_loss: 0.4668 - val_accuracy: 0.8771
# Epoch 77/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.1864 - accuracy: 0.9439 - val_loss: 0.4715 - val_accuracy: 0.8774
# Epoch 78/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.1837 - accuracy: 0.9444 - val_loss: 0.4771 - val_accuracy: 0.8767
# Epoch 79/100
# 125/125 [==============================] - 2s 20ms/step - loss: 0.1819 - accuracy: 0.9450 - val_loss: 0.4760 - val_accuracy: 0.8774
# Epoch 80/100
# 125/125 [==============================] - 2s 20ms/step - loss: 0.1794 - accuracy: 0.9458 - val_loss: 0.4801 - val_accuracy: 0.8771
# Epoch 81/100
# 125/125 [==============================] - 2s 20ms/step - loss: 0.1770 - accuracy: 0.9464 - val_loss: 0.4763 - val_accuracy: 0.8778
# Epoch 82/100
# 125/125 [==============================] - 2s 20ms/step - loss: 0.1746 - accuracy: 0.9472 - val_loss: 0.4804 - val_accuracy: 0.8768
# Epoch 83/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.1726 - accuracy: 0.9476 - val_loss: 0.4801 - val_accuracy: 0.8771
# Epoch 84/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.1700 - accuracy: 0.9489 - val_loss: 0.4831 - val_accuracy: 0.8779
# Epoch 85/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.1680 - accuracy: 0.9490 - val_loss: 0.4917 - val_accuracy: 0.8771
# Epoch 86/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.1659 - accuracy: 0.9498 - val_loss: 0.4901 - val_accuracy: 0.8758
# Epoch 87/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.1637 - accuracy: 0.9503 - val_loss: 0.4915 - val_accuracy: 0.8763
# Epoch 88/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.1612 - accuracy: 0.9513 - val_loss: 0.4949 - val_accuracy: 0.8768
# Epoch 89/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.1597 - accuracy: 0.9517 - val_loss: 0.4970 - val_accuracy: 0.8768
# Epoch 90/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.1571 - accuracy: 0.9524 - val_loss: 0.5010 - val_accuracy: 0.8763
# Epoch 91/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.1549 - accuracy: 0.9531 - val_loss: 0.5013 - val_accuracy: 0.8762
# Epoch 92/100
# 125/125 [==============================] - 3s 21ms/step - loss: 0.1532 - accuracy: 0.9535 - val_loss: 0.5027 - val_accuracy: 0.8766
# Epoch 93/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.1511 - accuracy: 0.9543 - val_loss: 0.5069 - val_accuracy: 0.8767
# Epoch 94/100
# 125/125 [==============================] - 2s 20ms/step - loss: 0.1494 - accuracy: 0.9549 - val_loss: 0.5121 - val_accuracy: 0.8760
# Epoch 95/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.1476 - accuracy: 0.9553 - val_loss: 0.5107 - val_accuracy: 0.8757
# Epoch 96/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.1459 - accuracy: 0.9557 - val_loss: 0.5115 - val_accuracy: 0.8765
# Epoch 97/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.1440 - accuracy: 0.9562 - val_loss: 0.5154 - val_accuracy: 0.8764
# Epoch 98/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.1421 - accuracy: 0.9569 - val_loss: 0.5174 - val_accuracy: 0.8756
# Epoch 99/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.1405 - accuracy: 0.9571 - val_loss: 0.5228 - val_accuracy: 0.8752
# Epoch 100/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.1389 - accuracy: 0.9576 - val_loss: 0.5290 - val_accuracy: 0.8756
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: s2s/assets
# INFO:tensorflow:Assets written to: s2s/assets

# %% [markdown]
# ## Run inference (sampling)
#
# 1. encode input and retrieve initial decoder state
# 2. run one step of decoder with this initial state
# and a "start of sequence" token as target.
# Output will be the next target token.
# 3. Repeat with the current target token and current states

# %%
# Define sampling models
# Restore the model and construct the encoder and decoder.
model = keras.models.load_model("s2s")

encoder_inputs = model.input[0]  # input_1
encoder_outputs, state_h_enc, state_c_enc = model.layers[2].output  # lstm_1
encoder_states = [state_h_enc, state_c_enc]
encoder_model = keras.Model(encoder_inputs, encoder_states)

decoder_inputs = model.input[1]  # input_2
decoder_state_input_h = keras.Input(shape=(latent_dim,))
decoder_state_input_c = keras.Input(shape=(latent_dim,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
decoder_lstm = model.layers[3]
decoder_outputs, state_h_dec, state_c_dec = decoder_lstm(
    decoder_inputs, initial_state=decoder_states_inputs
)
decoder_states = [state_h_dec, state_c_dec]
decoder_dense = model.layers[4]
decoder_outputs = decoder_dense(decoder_outputs)
decoder_model = keras.Model(
    [decoder_inputs] + decoder_states_inputs, [decoder_outputs] + decoder_states
)

# Reverse-lookup token index to decode sequences back to
# something readable.
reverse_input_char_index = dict((i, char) for char, i in input_token_index.items())
reverse_target_char_index = dict((i, char) for char, i in target_token_index.items())


def decode_sequence(input_seq):
    # Encode the input as state vectors.
    states_value = encoder_model.predict(input_seq)

    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1, 1, num_decoder_tokens))
    # Populate the first character of target sequence with the start character.
    target_seq[0, 0, target_token_index["\t"]] = 1.0

    # Sampling loop for a batch of sequences
    # (to simplify, here we assume a batch of size 1).
    stop_condition = False
    decoded_sentence = ""
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict([target_seq] + states_value)

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = reverse_target_char_index[sampled_token_index]
        decoded_sentence += sampled_char

        # Exit condition: either hit max length
        # or find stop character.
        if sampled_char == "\n" or len(decoded_sentence) > max_decoder_seq_length:
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1, 1, num_decoder_tokens))
        target_seq[0, 0, sampled_token_index] = 1.0

        # Update states
        states_value = [h, c]
    return decoded_sentence

# %% [markdown]
# You can now generate decoded sentences as such:

# %%
for seq_index in range(20):
    # Take one sequence (part of the training set)
    # for trying out decoding.
    input_seq = encoder_input_data[seq_index : seq_index + 1]
    decoded_sentence = decode_sequence(input_seq)
    print("-")
    print("Input sentence:", input_texts[seq_index])
    print("Decoded sentence:", decoded_sentence)
# Out:
# 1/1 [==============================] - 0s 437ms/step
# 1/1 [==============================] - 0s 477ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# -
# Input sentence: Go.
# Decoded sentence: Pars !
#
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 29ms/step
# -
# Input sentence: Go.
# Decoded sentence: Pars !
#
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# -
# Input sentence: Go.
# Decoded sentence: Pars !
#
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# -
# Input sentence: Go.
# Decoded sentence: Pars !
#
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# -
# Input sentence: Hi.
# Decoded sentence: Salut !
#
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# -
# Input sentence: Hi.
# Decoded sentence: Salut !
#
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# -
# Input sentence: Run!
# Decoded sentence: Fuyons !
#
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# -
# Input sentence: Run!
# Decoded sentence: Fuyons !
#
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# -
# Input sentence: Run!
# Decoded sentence: Fuyons !
#
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# -
# Input sentence: Run!
# Decoded sentence: Fuyons !
#
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# -
# Input sentence: Run!
# Decoded sentence: Fuyons !
#
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# -
# Input sentence: Run!
# Decoded sentence: Fuyons !
#
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# -
# Input sentence: Run!
# Decoded sentence: Fuyons !
#
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# -
# Input sentence: Run!
# Decoded sentence: Fuyons !
#
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# -
# Input sentence: Run.
# Decoded sentence: Fuyez !
#
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# -
# Input sentence: Run.
# Decoded sentence: Fuyez !
#
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 22ms/step
# -
# Input sentence: Run.
# Decoded sentence: Fuyez !
#
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# -
# Input sentence: Run.
# Decoded sentence: Fuyez !
#
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# -
# Input sentence: Run.
# Decoded sentence: Fuyez !
#
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# -
# Input sentence: Run.
# Decoded sentence: Fuyez !
